// %% [markdown]
// # 1  Les cellulles Jupyter code:
//
// Les cellulles permettent d’exécuter directement des instructions javascript.
//
// Par exemple, si vous tapez `1+1`, vous obtenez `2`.
//
// # à faire:
//
//  Tapez 1+1, faites **shift-enter**.

// %% [markdown]
// Si vous voulez affichez des valeurs intermédiares et des textes avant le calcul final, vous pouvez utilisez `console.log()`
// Executez le code suivant.

// %%
console.log("x:"+5+"\n")
console.log("Bonjour")

// %% [markdown]
// # 2 Les nombres
// ## type de nombres
// Les nombres en JavaScript sont implémentés comme des nombres sur 64 bits  à précision double selon le format IEEE-754 qui est un standard pour la  représentation des nombres flottants et qui permet d'avoir jusqu'à 16  chiffres significatifs.
//
// Ce format permet de représenter des nombres  entre -(2^53-1) et 2^53-1.
//
// **Il n'existe pas de type spécifique pour les entiers en JavaScript**.
//
// Le type numérique possède également trois valeurs spéciales symboliques :
// - [Infinity](https://developer.mozilla.org/fr/docs/Web/JavaScript/Reference/Objets_globaux/Infinity)
// - [-Infinity](https://developer.mozilla.org/fr/docs/Web/JavaScript/Reference/Global_Objects/Number/NEGATIVE_INFINITY)
// - [NaN](https://developer.mozilla.org/fr/docs/Web/JavaScript/Reference/Objets_globaux/NaN) (pour désigner une valeur qui n'est pas un nombre).
//
// ## opérations
// Les [opérateurs arithmétiques](https://developer.mozilla.org/fr/docs/Web/JavaScript/Reference/Op%C3%A9rateurs/Op%C3%A9rateurs_arithm%C3%A9tiques)  ont pour opérandes des valeurs numériques et renvoient une valeur numérique.
//
// Les opérateurs  arithmétiques standards sont
// - l'addition (+)
// - la soustraction (-)
// - la  multiplication (*)
// - la division (/).
//
// Ces opérateurs fonctionnent  comme pour la plupart des langages de programmation lorsqu'ils sont  utilisés avec des nombres décimaux (on notera que la division par zéro a  pour résultat [Infinity](https://developer.mozilla.org/fr/docs/Web/JavaScript/Reference/Objets_globaux/Infinity)).
//
// - [Reste](https://developer.mozilla.org/fr/docs/Web/JavaScript/Reference/Op%C3%A9rateurs/Op%C3%A9rateurs_arithm%C3%A9tiques#Reste_(.25)) (`%`):Renvoie le reste entier de la division entre les deux opérandes. 12 % 5 renvoie 2.
// - Puissance (`**`)   Calcule un nombre (base) élevé à une puissance donnée. `2**3` renvoie `8`. `10**(-1)` renvoie `0.1`
//
// # à faire
//
//  1. Calculer $(4.1+3.6)\times5.3+2$

// %% [markdown]
// 2. Calculer $0.1+0.2-0.3$

// %% [markdown]
// 3. Calculer $3^{50}$

// %% [markdown]
//  # 3 Number:
//
//  L'objet **`Number`** est une enveloppe objet autour du [type primitif numérique](https://developer.mozilla.org/fr/docs/Web/JavaScript/Structures_de_donn%C3%A9es#Le_type_nombre). Autrement dit, il est utilisé pour manipuler les nombres comme des objets. Pour créer un objet `Number`, on utilise le constructeur `Number()`.
//
// # à faire
// 1. Que donne `Number(3)`?

// %% [markdown]
// 2. Que donne `Number("3")`?

// %% [markdown]
// 3. Que donne `Number("Bonjour!")`?

// %% [markdown]
// 4. Que donne  `Number.EPSILON`?

// %% [markdown]
// 5. Que donne `Number.MAX_SAFE_INTEGER`?

// %% [markdown]
// 6. Que donne `Number.MAX_VALUE`?

// %% [markdown]
// 7. Que donne `Number.MAX_VALUE*2`?

// %% [markdown]
// # 4 Math
//
//  L'objet **`Math`** est un objet natif dont les  méthodes et propriétés permettent l'utilisation de constantes et  fonctions mathématiques. Cet objet n'est pas une fonction.
//
// # à faire
//
// 1. Que fait `Math.PI`?

// %% [markdown]
// 2. Que fait `Math.floor(2.3)`?

// %% [markdown]
// 3. Que fait `Math.floor(41.231)`?

// %% [markdown]
// 4. Que fait `Math.floor(-2.3)`?

// %% [markdown]
// 5. Que fait `Math.random()`?

// %% [markdown]
// 6. Que fait `Math.random()`?

// %% [markdown]
// 7. Que fait `Math.floor(Math.random()*6)`?

// %% [markdown]
// 8. Que fait `Math.floor(Math.random()*6)`?

// %% [markdown]
// 9. Que fait `Math.floor(Math.random()*6)`?

// %% [markdown]
// # 5 Variables
//
// Une variable est un conteneur pour une valeur, tel un nombre à utiliser  pour une addition, ou une chaîne devant faire partie d'une phrase. Mais  un aspect spécial des variables est que les valeurs contenues peuvent  changer.
//
// On déclare les variables avec les mots `var` ou `let`.
// Lorsque des variables ne changeront pas de valeur, on peut utiliser `const`.
//
// Une bonne habitude consiste à déclarer les variables en début de programme (si possible dans les fonctions) et à leur assigner( signe `=` ) une valeur plus tard (il ne faut pas oublier de les initialiser).
//
// On utilise souvent plusieurs mots pour nommer une variable. L'usage consiste à écrire le premier mot en minuscule et à mettre une Majuscule au début de chaque mot suivant comme par exemple `maNoteDuBacEnNsi`.
//
// # à faire
//
// 1. Exécuter le code suivant.
// 2. Mettre votre age dans la variable `monAge` et réexcuter le code modifié.

// %%
var x, // déclaration des variables
    y,
    monAge,
    temp;
x=5; // initialisation des variables
y=-7.36;
temp=0
console.log("x: "+x+"\n");
console.log("y: "+y+"\n");    
console.log("monAge: "+monAge+"\n");

// %% [markdown]
// 3. Que fait `x+y`?

// %% [markdown]
// 4. Que fait `x*y`?

// %% [markdown]
// 5. Que fait le code suivant?
// ```js
// x=1;
// x=x+2;
// x;
// ```

// %% [markdown]
// 6. Que fait le code suivant?
// ```js
// temp=x;
// x=y;
// y=temp;
// ```

// %% [markdown]
// # 6 Les fonctions
//
// Les fonctions font partie des briques fondamentales  de JavaScript. Une fonction est une procédure JavaScript, un ensemble  d'instructions effectuant une tâche ou calculant une valeur. Afin  d'utiliser une fonction, il est nécessaire de l'avoir auparavant définie  au sein de la portée dans laquelle on souhaite l'appeler.
//
// Une **définition de fonction** (aussi appelée **déclaration de fonction** ou **instruction de fonction**) est construite avec le mot-clé [function](https://developer.mozilla.org/fr/docs/Web/JavaScript/Reference/Instructions/function), suivi par :
//
// - Le nom de la fonction.
// - Une liste d'arguments à passer à la fonction, entre parenthèses et séparés par des virgules.
// - Les instructions JavaScript définissant la fonction, entre accolades, `{ }`.
//
// Le code suivant, par exemple, définit une fonction intitulée `carré` :
//
// ```js
// function carre(nombre) {
//   return nombre * nombre;
// }
// ```
//
// La fonction `carré` prend un seul argument, appelé `nombre`. La fonction est composée d'une seule instruction qui renvoie l'argument de la fonction (`nombre`) multiplié par lui-même. L'instruction [return](https://developer.mozilla.org/fr/docs/Web/JavaScript/Reference/Instructions/return) spécifie la valeur qui est renvoyée par la fonction.
//
// # à faire
//
// 1. Ecrire la fonction `carre` et la tester en executant `carre(5)`.

// %% [markdown]
// 2. Écrire une fonction `cube` et la tester.

// %% [markdown]
// 3. Écrire une fonction `ftoc` qui convertit des degrés fahrenheit en degrés celsius et la tester.

// %% [markdown]
// # Exercices sur les fonctions
//
//
// 1. Voici un programme de calcul venant d'un sujet de brevet.
//
// - Prendre un nombre
// - Lui ajouter 8
// - Multiplier le résultat par 3
// - Enlever 24
// - Enlever le nombre de départ
//
// La fonction `f1` ci-dessous permet de faire ce calcul.
// ```js
// function f1(nombre){
//   var resultat;
//   resultat=nombre;
//   resultat=resultat + 8;
//   resultat=resultat * 3;
//   resultat=resultat - 24;
//   resultat=resultat - nombre;
//   return resultat
// }
// ```
// combien font f1(-3), f1(0), f1(4) ?

// %% [markdown]
// 2. Construire une fonction f2 permettant de résoudre le problème suivant.
//
//  - Choisir un nombre
//  - Ajouter 1
//  - Calculer le carré de cette somme
//  - Soustraire 9 au résultat
//
// et la tester sur plusieurs valeurs.

// %% [markdown]
// 3. Construire une fonction f3 permettant de résoudre le problème suivant.
//
//  - Choisir un nombre.
//  - Soustraire 6.
//  - Multiplier le résultat obtenu par le nombre choisi.
//  - Ajouter 9.
//
// et la tester sur plusieurs valeurs.

// %% [markdown]
// 4. Un tour de magie (facultatif)
//
// Un magicien demande à un spectateur de penser à un nombre et de l'écrire sur une ardoise.
//
// Il l'invite à cacher cette ardoise le temps du numéro.
//
// Il lui demande d'ajouter 3 puis de multiplier cette somme par le nombre auquel il a pensé au départ.
//
// Il insiste : ne pas oublier ce résultat, puis calculer le carré du nombre de départ.
//
// Enfin il demande de soustraire ce résultat du précédent.
// Au spectateur un peu hagard après tous ces calculs, le magicien demande de dire à haute voix le résultat final.
//
// Instantanément le magicien annonce le nombre pensé déclenchant une salve d'applaudissements alors que le spectateur brandit son ardoise en preuve.
//
// Comment fait le magicien? (utilisez une fonction)

// %% [markdown]
//
//
// # 7 Les chaînes de caractères
//
// Les chaînes de caractères peuvent avoir l'une des formes suivantes :
//
// ```js
// 'texte de chaînes de caractères'
// "texte de chaînes de caractères"
// ```
//
// En dehors des caractères classiques, des **caractères spéciaux** peuvent être encodés grâce à l'échappement :
//
// `\'` simple quote
//
// `\"` double quote
//
// `\\` barre oblique inversée
//
//  `\n` nouvelle ligne
//
//  `\t` tabulation
//
//  `\uXXXX` point de code Unicode
//
// Il peut arriver que le code contienne des **chaînes** plutôt **longues**. Plutôt que d'avoir des lignes qui s'étirent sur tout le fichier et dans un éditeur de code, il est possible de casser la chaîne sur plusieurs lignes sans que cela modifie le contenu de la chaîne. Il existe deux façons pour le faire :
//
// ```js
// chaîneLongue = "Voici une très longue chaîne qui a besoin " +
//                    " d'être passée à la ligne parce que sinon " +
//                    " ça risque de devenir illisible.";
// ```
//
// ou
//
// ```js
// chaîneLongue = "Voici une très longue chaîne qui a besoin \
//                    d'être passée à la ligne parce que sinon \
//                    ça risque de devenir illisible.";
// ```
//
// **Accéder à un caractère**
//
// On considère la chaine comme une liste
//
// ```js
// s="chat"
// ```
//
// ```js
// s[2]; // renvoie "a"
// ```
//
// **longueur**
//
// ```js
// "chat".length.; // renvoie 4
// ```
//
// **Concaténation**
//
// ```js
// "Un "+"chat";// renvoie "Un chat"
// ```
//
// # à faire
// 1. Calculez 1+1 .

// %% [markdown]
// 2. Calculez "1"+1 .

// %% [markdown]
// 3. Créer une fonction `bonjour` qui aurait le comportement suivant:
// ```js
// bonjour("Alan Turing")
// ```
// renvoie
// ```js
// "Bonjour Alan Turing!"
// ```
// Testez la avec d'autres noms et prénoms.

// %%
bonjour("Alan Turing")

// %% [markdown]
// # 8 Type de donnée
//
// L'opérateur `typeof` retourne les informations de type sous forme d'une chaîne de caractères. Six valeurs différentes peuvent être retournées par l'opérateur `typeof` : `number`, `string`, `boolean`, `object`, `function` et `undefined`.
//
// # à faire
//
// 1. Quel est le type de `5`?

// %% [markdown]
// 2. Quel est le type de `Math.PI`?

// %% [markdown]
// 3. Quel est le type de `"5"`?

// %% [markdown]
// 4. Quel est le type de `"Il fait beau."`?

// %% [markdown]
// 5. Quel est le type de `x`?

// %% [markdown]
// 6. On définit
// ```js
// function f(x){return x}
// ```
// Quel est le type de `f`?

// %% [markdown]
// # 9 Les booléens
//
// En informatique, un **booléen** est un type de données logique qui ne peut prendre que deux valeurs : `true` _(vrai)_ ou `false` _(faux)_.  Par exemple, en JavaScript, les conditions booléennes sont souvent utilisée pour décider quelle section de code doit être exécutée (comme  dans l'[instruction If](https://developer.mozilla.org/fr/docs/Web/JavaScript/Reference/Instructions/if...else)) ou répétée (comme pour une [boucle For](https://developer.mozilla.org/fr/docs/Web/JavaScript/Reference/Instructions/for)).
//
//
// **opérateurs de comparaison**.
// <table>
//     <tr>
//         <td>1.</td>
//         <td>===</td>
//         <td>Égalité stricte</td>
//         <td>Teste si les valeurs de droite et de gauche sont identiques<td>
//     </tr>
//     <tr>
//         <td>2.</td>
//         <td>!==</td>
//         <td>Non-égalité stricte</td>
//         <td>Teste si les valeurs de doite et de gauche ne sont pas identiques<td>
//     </tr>
//      <tr>
//         <td>3.</td>
//         <td><</td>
//         <td>Inférieur à</td>
//         <td>Teste si la valeur de gauche est plus petite que celle de droite.<td>
//     </tr>
//     <tr>
//         <td>4.</td>
//         <td>></td>
//         <td>Supérieur à</td>
//         <td>Teste si la valeur de gauche est plus grande que celle de droite.<td>
//     </tr>
//     <tr>
//         <td>5.</td>
//         <td><=</td>
//         <td>Inférieur ou égal à</td>
//         <td>Teste si la valeur de gauche est plus petite ou égale à celle de droite.<td>
//     </tr>
//     <tr>
//         <td>6.</td>
//         <td>>=</td>
//         <td>Supérieur ou égal à</td>
//         <td>Teste si la valeur de gauche est supérieure ou égale à celle de droite.<td>
//     </tr>
//
// </table>
//
//
// # à faire
// 1. Que donne `5 === 2 + 4`?

// %% [markdown]
// 2. Que donne `5 !== 2 + 3`?

// %% [markdown]
// 3. Que donne `10<16`?

// %% [markdown]
// 4. Que donne `20>=20`?

// %% [markdown]
// 5. Que donne `x<16`?

// %% [markdown]
// 6. Que donne `"ab"==="ab"`?

// %% [markdown]
// 7. Que donne `"bonjour"==="Bonjour"`?

// %% [markdown]
// # 10 If
//
// instruction conditionnelle [if ... else](https://developer.mozilla.org/fr/docs/Web/JavaScript/Reference/Instructions/if...else).
//
// ```js
// if (condition) {
//   code à exécuter si la condition est true
// } else {
//   sinon exécuter cet autre code à la place
// }
// ```
//
// Ici nous avons:
//
// 1. Le mot‑clé `if` suivie de parenthèses.
// 2. Une condition à évaluer, placée entre les parenthèses (typiquement  « cette valeur est‑elle plus grande que cet autre valeur ? » ou « cette  valeur existe‑t‑elle ? »). Cette condition se servira des [opérateurs de comparaison](https://developer.mozilla.org/fr/docs/Learn/JavaScript/First_steps/Math#Comparison_operators) et renverra `true` ou `false`.
// 3. Une paire d'accolades, à l'intérieur de laquelle se trouve  du code; il sera exécuté  seulement si la condition renvoie `true`.
// 4. Le mot‑clé `else`.
// 5. Une autre paire d'accolades, à l'intérieur de laquelle se trouve  du code différent — tout code souhaité et il sera exécuté seulement si  la condition ne renvoie pas `true`.
//
// Ce code est facile à lire pour une personne — il dit « **si** la **condition** renvoie `true`, exécuter le code A, **sinon** exécuter le code B ».
//
// Notez qu'il n'est pas nécessaire d'inclure une instruction `else` et le deuxième bloc entre accolades — le code suivant est aussi parfaitement correct :
//
// ```js
// if (condition) {
//   code à exécuter si la condition est true
// }
// ```
//
// # à faire
//
// 1. Compléter  la fonction `f` qui teste si un nombre est positif ou négatif.

// %%
function f(nombre){
  
}


// On doit obtenir :"2 est positif."
console.log(f(2));

// On doit obtenir :"-2 est négatif."
console.log(f(-2));

// %% [markdown]
// 2. Complétez la fonction `max` qui doit donner le plus grand des deux nombres.

// %%
function max(x,y){
  
}

console.log(max(2,3));
console.log(max(4,3));
console.log(max(3,3));

// %% [markdown]
// 3. Le jeu du nombre mystérieux consiste à deviner un nombre compris entre 0 et 100 en faisant des propositions successives. Après chaque proposition erronée, le joueur est informée si celle-ci était plus petite ou plus grande que le nombre à découvrir.
//
//    a. Complétez la fonction `initialisation` .
//    - Elle doit mettre le `compteur` à 0 et mettre un nombre entier aléatoire entre 0 et 100 dans `nbMyst`.
//
//    b. Complétez la fonction `test`.
//    - Elle doit dire si le nombre testé `nombre` est plus grand ou plus petit que le nombre `nbMyst` et augmenter `compteur` de 1.
//    - Si le nombre proposé est le nombre `nbMyst`, elle doit féliciter le joueur et lui dire en combien d'essai, il a réussi.

// %%
let nbMyst,
    compteur;
    
function initialisation(){
  
}

function test(nombre){
  
}

initialisation()
test(50)

// %% [markdown]
// 4. Compléter la fonction `interupteur` pour qu'elle change la valeur de la variable `etat`.
//
// Si `etat` a pour valeur `"eteint"`, sa nouvelle valeur doit être `"allume"`.
//
// Si `etat` a pour valeur `"allume"`, sa nouvelle valeur doit être `"eteint"`.
//
// Testez plusieurs fois la fonction dans la console.
//
// **Remarques:**
//
// la variable `etat` est ce que l'on appelle une variable globale. Elle est définie en dehors d'une fonction.
//
// `interupteur()` est un exemple de fonction ne prenant pas d'argument. `Math.random()` en était une autre.

// %%
let etat="eteint";

function interupteur(){
    
    
  
  return etat;
}

console.log(interupteur());
// on doit obtenir "allume"

console.log(interupteur());
// on doit obtenir "eteint"

// %% [markdown]
// 5. (Facultatif) Compléter la fonction ci dessous qui doit résoudre des équations du second degré.
//
// Testez la fonction sur différentes valeurs.

// %%
function secondDegre(a,b,c){
  
}

console.log(secondDegre(1,0,-1));
// on doit obtenir "L'équation admet deux solutions: 1 et -1"

console.log(secondDegre(1,2,1));
// on doit obtenir "L'équation admet une unique solution: 1"

console.log(secondDegre(1,1,1));
// on doit obtenir "L'équation n'admet pas de solutions"

// %% [markdown]
// # 11 Les boucles for
//
// Les boucles permettent de répéter des actions simplement et rapidement.  Une boucle peut être vue comme une version informatique de « copier N  lignes » ou de « faire X fois quelque chose ». Par exemple, en  JavaScript, on pourrait traduire « Faire 5 pas vers l'est » avec cette  boucle :
// ```js
// for ( var pas = 0; pas < 5; pas++) {
//   // Ceci sera exécuté 5 fois
//   // la variable "pas" ira de 0 à 4
//   console.log("Faire un pas vers l'est");
// }
// ```
//
// # à faire
//
// 1. Écrire une fonction `test(n)` où `n` est un entier strictement positif et qui doit avoir le comportement suivant.
//
// ```js
// test(4);
// ```
// On doit obtenir:
// ```
// La variable i vaut: 0
// La variable i vaut: 1
// La variable i vaut: 2
// La variable i vaut: 3
// ```

// %% [markdown]
// 2. a. Testez la fonction `multipleDe7` suivante en prenant 5 puis 11 pour `n`.
// ```js
// function multipleDe7(n){
//   let resultat="";
//   for(let i=0;i<n;i=i+1) {
//     resultat=resultat+i+"  ";
//   }
//   return resultat;
// }
// ```

// %% [markdown]
// b. Écrire une fonction `tableDes7` pour que `console.log(tableDes7(10))` donne:
// ```
// 7x0=0  7x1=7  7x2=14  7x3=21  7x4=28  7x5=35  7x6=42  7x7=49  7x8=56  7x9=63
// ```

// %% [markdown]
// 3. a. Completer la fonction `ligneEtoile(n)` pour qu'elle ait le comportement attendu.
//
// ```js
// console.log(ligneEtoile(2));
// ```
// doit donner
// ```
// **
// ```
// et
// ```js
// console.log(ligneEtoile(10));
// ```
// doit donner
// ```
// **********
// ```

// %%
function ligneEtoile(n){
  let resultat="";
  for( let i =0; i<n; i=i+1) {
    //completez ici
  }
  return resultat;
}

/*
On doit obtenir:
**
*/
console.log(ligneEtoile(2));

/*
On doit obtenir:
**********
*/
console.log(ligneEtoile(10));

// %% [markdown]
// b. En utilisant la fonction `ligneEtoile(n)`, écrire une fonction `rectangleEtoile(largeur,hauteur)` qui dessine un rectangle d'étoiles. Par exemple, `rectangleEtoile(42,7)` doit donner:
//
//
// ```
// ******************************************
// ******************************************
// ******************************************
// ******************************************
// ******************************************
// ******************************************
// ******************************************
// ```

// %%
console.log(rectangleEtoile(42,7));

// %% [markdown]
// c. En utilisant la fonction `ligneEtoile(n)`, écrire une fonction `triangleEtoile(n)` qui dessine un rectangle d'étoiles.
// Par exemple, `triangleEtoile(7)` doit donner:
// ```
// *
// **
// ***
// ****
// *****
// ******
// *******
// ```

// %%
console.log(triangleEtoile(7));

// %% [markdown]
// # 12 Les boucles while
// L'instruction `while` permet de créer une boucle qui s'exécute tant qu'une condition de test est vérifiée.
// Cette instruction while s'utilise de la façon suivante :
// ```js
// while (condition){
//   instruction
// }
// ```
// Si la **condition** n'est pas vérifiée, l'instruction **instruction** n'est pas exécutée et le contrôle passe directement à l'instruction suivant la boucle.
// # à faire
//
// 1. Ecrire une fonction `de()` qui simule un lancer de dés. le résultat doit être un nombre entier

// %%
de()

// %% [markdown]
// 2. Ecrire une fonction qui renvoie le nombre de lancers de dés nécessaires pour obtenir un 6

// %%
nbLancer()
